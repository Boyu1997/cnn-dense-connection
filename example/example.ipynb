# %% [markdown]
# # Example
#
# ## Introduction
# TBD
#
# ## Training Demo
#
# ### Example traing script
# Train under the defult architecture for 10 epoch and batch size of 16. Train for only the first batch per epoch so that the script will not take too long to execute.

# %%
# !python3 ../main.py --ep=10 --bsize=16 --one_batch
# Out:
# Namespace(bottleneck=4, bsize=16, cross_block_rate=1, end_block_reduction_rate=0.5, ep=10, group_1x1=4, group_3x3=4, growth=[8, 16, 32], lr=0.1, n_gpu=4, one_batch=True, optimizer='sgd', parallel=False, save_folder='default', scheduler='cos', stages=[10, 10, 10])
# Using device: cpu
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1/10.. (Training Time: 1.51s Running Learning Rate: 0.10000)
#     Train - Loss: 2.2958 Accuracy: 0.062
#     Validate - Loss: 2.3899 Accuracy: 0.000
# Epoch: 2/10.. (Training Time: 1.72s Running Learning Rate: 0.09755)
#     Train - Loss: 3.8217 Accuracy: 0.125
#     Validate - Loss: 2.2510 Accuracy: 0.062
# Epoch: 3/10.. (Training Time: 1.69s Running Learning Rate: 0.09045)
#     Train - Loss: 2.7079 Accuracy: 0.188
#     Validate - Loss: 2.4036 Accuracy: 0.062
# Epoch: 4/10.. (Training Time: 1.62s Running Learning Rate: 0.07939)
#     Train - Loss: 2.9509 Accuracy: 0.062
# ...

# %% [markdown]
# ### Example testing script

# %%
# TBD

# %% [markdown]
# ## Result Showcase

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [18, 8]

import sys
sys.path.append("..")

from evaluation.training_plot import training_plot


densenet_list = ['densenet-original', 'cbr=0.2-rdc=0.5', 'cbr=0.4-rdc=0.5', 'cbr=0.6-rdc=0.5']
condensenet_list = ['condensenet-original', 'cbr=0.8-rdc=0.1', 'cbr=0.6-rdc=0.1', 'cbr=0.4-rdc=0.1']
training_plot('DenseNet and DenseNet Variations', 'result', densenet_list, '.json')
training_plot('CondenseNet and CondenseNet Variations', 'result', condensenet_list, '.json')
